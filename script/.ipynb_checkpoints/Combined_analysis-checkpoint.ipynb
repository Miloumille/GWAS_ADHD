# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
import glob

# %% [markdown]
# # Compare iHS and Tajima on continents

# %%
population_groups = {
    "AFR": ["ACB", "ASW", "ESN", "GWD", "LWK", "MSL", "YRI"],
    "AMR": ["CLM", "MXL", "PEL", "PUR"],
    "EAS": ["CDX", "CHB", "CHS", "JPT", "KHV"],
    "EUR": ["CEU", "FIN", "GBR", "IBS", "TSI"],
    "SAS": ["BEB", "GIH", "ITU", "PJL", "STU"]
}

# %%
rs_ids = pd.read_csv('../data/snp_coordinates_grch37.tsv', sep='\t')
iHS_scored = pd.DataFrame(columns=['continent', 'country', 'iHS_score', 'chromosome', 'rsID'])

rows = []
for continent, populations in population_groups.items():
    for pop in populations:
        for _, row in rs_ids.iterrows():
            rsID = row['rsID']
            chromosome = row['Chromosome']
            path = f"../ihs_hapbin_globalCM/{pop}/hapbin_globalCM/{pop}.chr{chromosome}.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.noCNV.snv.modAncDer.bcfCheck.hapbin.ihs.txt"
            ihs_data = pd.read_csv(path, sep='\t')
            match = ihs_data.loc[ihs_data['Location'] == rsID, 'iHS'].values
            iHS_score = match[0] if len(match) > 0 else None
            rows.append({
                'continent': continent,
                'country': pop,
                'iHS_score': iHS_score,
                'chromosome': chromosome,
                'rsID': rsID
            })
iHS_scored = pd.DataFrame(rows)

# %%
iHS_scored
# Out:
#     continent country  iHS_score  chromosome        rsID
# 0         AFR     ACB   0.136240           1    rs549845
# 1         AFR     ACB        NaN           2   rs1438898
# 2         AFR     ACB   3.153840           3   rs2886697
# 3         AFR     ACB        NaN           3   rs9877066
# 4         AFR     ACB  -0.375819           3   rs7613360
# ..        ...     ...        ...         ...         ...
# 697       SAS     STU        NaN          14  rs76284431
# 698       SAS     STU  -1.909980          16   rs1162202
# 699       SAS     STU        NaN          18  rs76857496
# 700       SAS     STU   0.925440          18   rs7506904
# 701       SAS     STU   0.930382          20   rs6082363
#
# [702 rows x 5 columns]

# %%
iHS_scored.groupby('rsID').agg(
    nan_count = ('iHS_score', lambda x: x.isna().sum())
).reset_index()
# Out:
#            rsID  nan_count
# 0    rs10875612          0
# 1    rs11255890          0
# 2   rs114142727         26
# 3    rs11596214          0
# 4     rs1162202          6
# 5     rs1438898          6
# 6    rs17576773         12
# 7    rs17718444          5
# 8     rs2025286          0
# 9     rs2311059          0
# 10    rs2582895          0
# 11    rs2886697          8
# 12    rs4916723          0
# 13    rs4925811          4
# 14     rs549845          0
# 15    rs6082363          0
# 16    rs6537401          4
# 17     rs704061          0
# 18   rs73145587         26
# 19    rs7506904          0
# 20    rs7613360          0
# 21   rs76284431         26
# 22   rs76857496         11
# 23      rs77960          7
# 24    rs7844069          0
# 25    rs9877066         26
# 26    rs9969232          6

# %%
iHS_scored = iHS_scored.groupby(['rsID', 'continent']).agg(
    nan_count = ('iHS_score', lambda x: x.isna().sum()),
    iHS_std = ('iHS_score', 'std'),
    iHS_mean = ('iHS_score', 'mean')
).reset_index()

# %%
Tajima_scores = pd.read_csv("../results/tajimas_d_results.csv",header=1)
Tajima_scores = Tajima_scores.rename(columns={Tajima_scores.columns[0]: 'rsID'})
Tajima_scores = Tajima_scores.melt(id_vars='rsID', var_name='continent', value_name='Tajima_score')

# %%
sorted(Tajima_scores["rsID"].unique()) == sorted(iHS_scored["rsID"].unique())
# Out:
# True

# %%
merged_results = pd.merge(iHS_scored, Tajima_scores, on=['rsID', 'continent'], how='inner')
merged_results
merged_results.to_csv('../results/merged_results.csv', index=False)

# %%
sns.scatterplot(data=merged_results, x='iHS_mean', y='Tajima_score', hue='continent')
plt.xlabel('iHS Score')
plt.ylabel('Tajima’s D')
plt.title('Comparison of iHS and Tajima’s D scores')
plt.show()
clean_df = merged_results[['iHS_mean', 'Tajima_score']].dropna()
corr = clean_df.corr(method='spearman')
print(corr)
# Out:
#               iHS_mean  Tajima_score
# iHS_mean      1.000000      0.004269
# Tajima_score  0.004269      1.000000
